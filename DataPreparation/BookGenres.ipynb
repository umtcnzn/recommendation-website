# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['genre_id','genre_name'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [genre_id, genre_name]
# Index: []

# %%
genres = ["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics", "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction", "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror", "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal", "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction", "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

df['genre_name'] = genres

# %%
df['genre_id'] = range(1, len(genres) + 1)

# %%
df
# Out:
#     genre_id          genre_name
# 0          1                 Art
# 1          2           Biography
# 2          3            Business
# 3          4           Chick Lit
# 4          5          Children's
# 5          6           Christian
# 6          7            Classics
# 7          8              Comics
# 8          9        Contemporary
# 9         10           Cookbooks
# 10        11               Crime
# 11        12              Ebooks
# 12        13             Fantasy
# 13        14             Fiction
# 14        15     Gay and Lesbian
# 15        16      Graphic Novels
# 16        17  Historical Fiction
# 17        18             History
# 18        19              Horror
# 19        20    Humor and Comedy
# 20        21               Manga
# 21        22              Memoir
# 22        23               Music
# 23        24             Mystery
# 24        25          Nonfiction
# 25        26          Paranormal
# 26        27          Philosophy
# ...

# %%
df.to_csv('bookGenres.csv',encoding='utf-8',index=False)

# %%
data = pd.read_csv('bookGenres.csv')
data
# Out:
#     genre_id          genre_name
# 0          1                 Art
# 1          2           Biography
# 2          3            Business
# 3          4           Chick Lit
# 4          5          Children's
# 5          6           Christian
# 6          7            Classics
# 7          8              Comics
# 8          9        Contemporary
# 9         10           Cookbooks
# 10        11               Crime
# 11        12              Ebooks
# 12        13             Fantasy
# 13        14             Fiction
# 14        15     Gay and Lesbian
# 15        16      Graphic Novels
# 16        17  Historical Fiction
# 17        18             History
# 18        19              Horror
# 19        20    Humor and Comedy
# 20        21               Manga
# 21        22              Memoir
# 22        23               Music
# 23        24             Mystery
# 24        25          Nonfiction
# 25        26          Paranormal
# 26        27          Philosophy
# ...
