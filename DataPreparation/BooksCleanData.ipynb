# %%
import pandas as pd

# %%
books = pd.read_csv('books.csv')
book_genre = pd.read_csv('bookGenres.csv')

# %%
books
# Out:
#          id   book_id  best_book_id   work_id  books_count        isbn  \
# 0         1   2767052       2767052   2792775          272   439023483
# 1         2         3             3   4640799          491   439554934
# 2         4      2657          2657   3275794          487    61120081
# 3         5      4671          4671    245494         1356   743273567
# 4         6  11870085      11870085  16827462          226   525478817
# ...     ...       ...           ...       ...          ...         ...
# 9270   9996   7130616       7130616   7392860           19   441019455
# 9271   9997    208324        208324   1084709           19  067973371X
# 9272   9998     77431         77431   2393986           60  039330762X
# 9273   9999   8565083       8565083  13433613            7    61711527
# 9274  10000      8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url', 'tag_id', 'tag_name', 'goodreads_book_id', 'count',
#        'genre', 'genres'],
#       dtype='object')

# %% [markdown]
# id,best_book_id,work_id,books_count,isbn13,title,small_image_url,tag_id,tag_name,goodreaders_book_id,count,genre -> will be deleted
#
# ## look at the ratings
# ## check deleted ones either

# %%
books = books.head(1100)

# %%
books
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        4      2657          2657   3275794          487    61120081
# 3        5      4671          4671    245494         1356   743273567
# 4        6  11870085      11870085  16827462          226   525478817
# ...    ...       ...           ...       ...          ...         ...
# 1095  1143  16102004      16102004  21912533           47  1476730105
# 1096  1144     14249         14249    718772           51    60959037
# 1097  1145      5204          5204    420701           52   452282829
# 1098  1146    102920        102920   2415847           37  006097625X
# 1099  1147   7842288       7842288  10937544           76   316077054
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books['genres'] = books['genres'].str.strip('[]')
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\2789590312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['genres'] = books['genres'].str.strip('[]')

# %%
books['genres']
# Out:
# 0       'contemporary', 'ebooks', 'fantasy', 'fiction'...
# 1       'classics', 'contemporary', 'fantasy', 'fictio...
# 2       'classics', 'contemporary', 'crime', 'fiction'...
# 3              'classics', 'ebooks', 'fiction', 'romance'
# 4          'contemporary', 'ebooks', 'fiction', 'romance'
#                               ...
# 1095       'contemporary', 'ebooks', 'fiction', 'romance'
# 1096      'contemporary', 'fiction', 'romance', 'science'
# 1097      'classics', 'contemporary', 'ebooks', 'fiction'
# 1098    'art', 'classics', 'comics', 'fiction', 'histo...
# 1099    'contemporary', 'ebooks', 'fantasy', 'fiction'...
# Name: genres, Length: 1100, dtype: object

# %%
genres_split = books['genres'].str.split(',', expand=True)

# Determine the maximum number of genres in any record
max_num_genres = genres_split.shape[1]

# Create new column names dynamically based on the maximum number of genres
new_columns = [f'Genre{i+1}' for i in range(max_num_genres)]

# Assign the new columns to the DataFrame
books[new_columns] = genres_split
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1143094082.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[new_columns] = genres_split
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1143094082.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[new_columns] = genres_split
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1143094082.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
books
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        4      2657          2657   3275794          487    61120081
# 3        5      4671          4671    245494         1356   743273567
# 4        6  11870085      11870085  16827462          226   525478817
# ...    ...       ...           ...       ...          ...         ...
# 1095  1143  16102004      16102004  21912533           47  1476730105
# 1096  1144     14249         14249    718772           51    60959037
# 1097  1145      5204          5204    420701           52   452282829
# 1098  1146    102920        102920   2415847           37  006097625X
# 1099  1147   7842288       7842288  10937544           76   316077054
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books['Genre3']
# Out:
# 0        'fantasy'
# 1        'fantasy'
# 2          'crime'
# 3        'fiction'
# 4        'fiction'
#            ...
# 1095     'fiction'
# 1096     'romance'
# 1097      'ebooks'
# 1098      'comics'
# 1099     'fantasy'
# Name: Genre3, Length: 1100, dtype: object

# %%
books['Genre8'][997]
# Out:
# " 'paranormal'"

# %%
books
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        4      2657          2657   3275794          487    61120081
# 3        5      4671          4671    245494         1356   743273567
# 4        6  11870085      11870085  16827462          226   525478817
# ...    ...       ...           ...       ...          ...         ...
# 1095  1143  16102004      16102004  21912533           47  1476730105
# 1096  1144     14249         14249    718772           51    60959037
# 1097  1145      5204          5204    420701           52   452282829
# 1098  1146    102920        102920   2415847           37  006097625X
# 1099  1147   7842288       7842288  10937544           76   316077054
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
for i in range(1, 15):
    column_name = f'Genre{i}'
    books[column_name] = books[column_name].str.replace("'", "")
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\3280647356.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[column_name] = books[column_name].str.replace("'", "")

# %%
books['Genre3'][20]
# Out:
# ' crime'

# %%
books['Genre4'].head(20)
# Out:
# 0         fiction
# 1         fiction
# 2         fiction
# 3         romance
# 4         romance
# 5         fiction
# 6            None
# 7           crime
# 8         history
# 9         fiction
# 10        romance
# 11         horror
# 12        fiction
# 13        history
# 14        fiction
# 15        fiction
# 16        fiction
# 17        fiction
# 18        romance
# 19     paranormal
# Name: Genre4, dtype: object

# %%
books['Genre8']
# Out:
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#            ...
# 1095           None
# 1096           None
# 1097           None
# 1098     philosophy
# 1099           None
# Name: Genre8, Length: 1100, dtype: object

# %%
books
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        4      2657          2657   3275794          487    61120081
# 3        5      4671          4671    245494         1356   743273567
# 4        6  11870085      11870085  16827462          226   525478817
# ...    ...       ...           ...       ...          ...         ...
# 1095  1143  16102004      16102004  21912533           47  1476730105
# 1096  1144     14249         14249    718772           51    60959037
# 1097  1145      5204          5204    420701           52   452282829
# 1098  1146    102920        102920   2415847           37  006097625X
# 1099  1147   7842288       7842288  10937544           76   316077054
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
for i in range(1,15):
    books[f'Genre{i}'] = books[f'Genre{i}'].str.strip()
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1936639918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[f'Genre{i}'] = books[f'Genre{i}'].str.strip()

# %%
books['Genre8'][997]
# Out:
# 'paranormal'

# %%
book_genre['genre_name'][25].lower() == books['Genre8'][997]
# Out:
# True

# %%
book_genre
# Out:
#     genre_id          genre_name
# 0          1                 Art
# 1          2           Biography
# 2          3            Business
# 3          4           Chick Lit
# 4          5          Children's
# 5          6           Christian
# 6          7            Classics
# 7          8              Comics
# 8          9        Contemporary
# 9         10           Cookbooks
# 10        11               Crime
# 11        12              Ebooks
# 12        13             Fantasy
# 13        14             Fiction
# 14        15     Gay and Lesbian
# 15        16      Graphic Novels
# 16        17  Historical Fiction
# 17        18             History
# 18        19              Horror
# 19        20    Humor and Comedy
# 20        21               Manga
# 21        22              Memoir
# 22        23               Music
# 23        24             Mystery
# 24        25          Nonfiction
# 25        26          Paranormal
# 26        27          Philosophy
# ...

# %%
for i in range(len(books)):
    for j in range(14):
        for k in range(len(book_genre)):
            if books[f'Genre{j+1}'][i] == book_genre['genre_name'][k].lower():
                books[f'Genre{j+1}'][i] = book_genre['genre_id'][k]
                break
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1820737199.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[f'Genre{j+1}'][i] = book_genre['genre_id'][k]
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1820737199.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[f'Genre{j+1}'][i] = book_genre['genre_id'][k]
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_17472\1820737199.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
pd.set_option('display.max_columns',None)
books
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 0        1   2767052       2767052   2792775          272   439023483
# 1        2         3             3   4640799          491   439554934
# 2        4      2657          2657   3275794          487    61120081
# 3        5      4671          4671    245494         1356   743273567
# 4        6  11870085      11870085  16827462          226   525478817
# ...    ...       ...           ...       ...          ...         ...
# 1095  1143  16102004      16102004  21912533           47  1476730105
# 1096  1144     14249         14249    718772           51    60959037
# 1097  1145      5204          5204    420701           52   452282829
# 1098  1146    102920        102920   2415847           37  006097625X
# 1099  1147   7842288       7842288  10937544           76   316077054
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
type(books['Genre1'][0])
# Out:
# numpy.int64

# %%
for i in range(14):
    if(i==2 or i==3):
        continue
    books = books.drop(f'Genre{i+1}',axis=1)

# %%
books = books.drop('id',axis=1)
books = books.drop('best_book_id',axis=1)
books = books.drop('work_id',axis=1)
books = books.drop('books_count',axis=1)
books = books.drop('isbn13',axis=1)
books = books.drop('original_title',axis=1)
books = books.drop('small_image_url',axis=1)
books = books.drop('tag_id',axis=1)
books = books.drop('tag_name',axis=1)
books = books.drop('goodreads_book_id',axis=1)
books = books.drop('count',axis=1)
books = books.drop('genre',axis=1)

# %%
books
# Out:
#        book_id        isbn                      authors  \
# 0      2767052   439023483              Suzanne Collins
# 1            3   439554934  J.K. Rowling, Mary GrandPré
# 2         2657    61120081                   Harper Lee
# 3         4671   743273567          F. Scott Fitzgerald
# 4     11870085   525478817                   John Green
# ...        ...         ...                          ...
# 1095  16102004  1476730105             Christina Lauren
# 1096     14249    60959037           Barbara Kingsolver
# 1097      5204   452282829            Joyce Carol Oates
# 1098    102920  006097625X                Scott McCloud
# 1099   7842288   316077054  Kami Garcia, Margaret Stohl
#
#       original_publication_year  \
# 0                        2008.0
# 1                        1997.0
# 2                        1960.0
# 3                        1925.0
# 4                        2012.0
# ...                         ...
# 1095                     2013.0
# ...

# %%
books.columns
# Out:
# Index(['book_id', 'isbn', 'authors', 'original_publication_year', 'title',
#        'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'genres', 'Genre3', 'Genre4'],
#       dtype='object')

# %%
books = books.drop('ratings_count',axis=1)
books = books.drop('work_ratings_count',axis=1)
books = books.drop('work_text_reviews_count',axis=1)
books = books.drop('isbn',axis=1)
books = books.drop('ratings_1',axis=1)
books = books.drop('ratings_2',axis=1)
books = books.drop('ratings_3',axis=1)
books = books.drop('ratings_4',axis=1)
books = books.drop('ratings_5',axis=1)
books = books.drop('genres',axis=1)

# %%
books
# Out:
#        book_id                      authors  original_publication_year  \
# 0      2767052              Suzanne Collins                     2008.0
# 1            3  J.K. Rowling, Mary GrandPré                     1997.0
# 2         2657                   Harper Lee                     1960.0
# 3         4671          F. Scott Fitzgerald                     1925.0
# 4     11870085                   John Green                     2012.0
# ...        ...                          ...                        ...
# 1095  16102004             Christina Lauren                     2013.0
# 1096     14249           Barbara Kingsolver                     2000.0
# 1097      5204            Joyce Carol Oates                     1996.0
# 1098    102920                Scott McCloud                     1993.0
# 1099   7842288  Kami Garcia, Margaret Stohl                     2010.0
#
#                                                   title language_code  \
# ...

# %%
books = books.rename(columns={'Genre3': 'Genre1'})

# %%
books = books.rename(columns={'Genre1': 'genre_1'})
books = books.rename(columns={'Genre4': 'genre_2'})

# %%
books
# Out:
#        book_id                      authors  original_publication_year  \
# 0      2767052              Suzanne Collins                     2008.0
# 1            3  J.K. Rowling, Mary GrandPré                     1997.0
# 2         2657                   Harper Lee                     1960.0
# 3         4671          F. Scott Fitzgerald                     1925.0
# 4     11870085                   John Green                     2012.0
# ...        ...                          ...                        ...
# 1095  16102004             Christina Lauren                     2013.0
# 1096     14249           Barbara Kingsolver                     2000.0
# 1097      5204            Joyce Carol Oates                     1996.0
# 1098    102920                Scott McCloud                     1993.0
# 1099   7842288  Kami Garcia, Margaret Stohl                     2010.0
#
#                                                   title language_code  \
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    1100 non-null   int64
#  1   authors                    1100 non-null   object
#  2   original_publication_year  1099 non-null   float64
#  3   title                      1100 non-null   object
#  4   language_code              1064 non-null   object
#  5   average_rating             1100 non-null   float64
#  6   image_url                  1100 non-null   object
#  7   genre_1                    1085 non-null   object
#  8   genre_2                    1006 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 77.5+ KB

# %%
books.describe()
# Out:
#             book_id  original_publication_year  average_rating
# count  1.100000e+03                1099.000000     1100.000000
# mean   3.300766e+06                1961.451319        4.018255
# std    5.926141e+06                 211.876519        0.233999
# min    1.000000e+00                -750.000000        3.220000
# 25%    1.090275e+04                1976.000000        3.867500
# 50%    5.366550e+04                2000.000000        4.020000
# 75%    5.365133e+06                2008.500000        4.180000
# max    2.905608e+07                2016.000000        4.770000

# %%
books.isnull().sum()
# Out:
# book_id                       0
# authors                       0
# original_publication_year     1
# title                         0
# language_code                36
# average_rating                0
# image_url                     0
# genre_1                      15
# genre_2                      94
# dtype: int64

# %%
books.nunique()
# Out:
# book_id                      1100
# authors                       695
# original_publication_year     175
# title                        1100
# language_code                   7
# average_rating                124
# image_url                     889
# genre_1                        18
# genre_2                        25
# dtype: int64

# %%
books = books.drop_duplicates()

# %%
books
# Out:
#        book_id                      authors  original_publication_year  \
# 0      2767052              Suzanne Collins                     2008.0
# 1            3  J.K. Rowling, Mary GrandPré                     1997.0
# 2         2657                   Harper Lee                     1960.0
# 3         4671          F. Scott Fitzgerald                     1925.0
# 4     11870085                   John Green                     2012.0
# ...        ...                          ...                        ...
# 1095  16102004             Christina Lauren                     2013.0
# 1096     14249           Barbara Kingsolver                     2000.0
# 1097      5204            Joyce Carol Oates                     1996.0
# 1098    102920                Scott McCloud                     1993.0
# 1099   7842288  Kami Garcia, Margaret Stohl                     2010.0
#
#                                                   title language_code  \
# ...

# %%
books = books.fillna('')

# %%
for x in books.index:
    if books.loc[x, 'genre_1'] == '' and books.loc[x, 'genre_2'] == '':
         books.drop(x,inplace=True)

# %%
books
# Out:
#        book_id                      authors original_publication_year  \
# 0      2767052              Suzanne Collins                    2008.0
# 1            3  J.K. Rowling, Mary GrandPré                    1997.0
# 2         2657                   Harper Lee                    1960.0
# 3         4671          F. Scott Fitzgerald                    1925.0
# 4     11870085                   John Green                    2012.0
# ...        ...                          ...                       ...
# 1095  16102004             Christina Lauren                    2013.0
# 1096     14249           Barbara Kingsolver                    2000.0
# 1097      5204            Joyce Carol Oates                    1996.0
# 1098    102920                Scott McCloud                    1993.0
# 1099   7842288  Kami Garcia, Margaret Stohl                    2010.0
#
#                                                   title language_code  \
# ...

# %%
books.nunique()
# Out:
# book_id                      1085
# authors                       686
# original_publication_year     175
# title                        1085
# language_code                   8
# average_rating                124
# image_url                     876
# genre_1                        18
# genre_2                        26
# dtype: int64

# %%
pd.set_option('display.max_colwidth',None)
duplicates = books[books.duplicated(subset='image_url', keep=False)]
duplicates['image_url']
# Out:
# 31      https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 40      https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 59      https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 73      https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 78      https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
#                                                   ...
# 1072    https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 1080    https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 1081    https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# 1083    https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# ...

# %%
books
# Out:
#        book_id                      authors original_publication_year  \
# 0      2767052              Suzanne Collins                    2008.0
# 1            3  J.K. Rowling, Mary GrandPré                    1997.0
# 2         2657                   Harper Lee                    1960.0
# 3         4671          F. Scott Fitzgerald                    1925.0
# 4     11870085                   John Green                    2012.0
# ...        ...                          ...                       ...
# 1095  16102004             Christina Lauren                    2013.0
# 1096     14249           Barbara Kingsolver                    2000.0
# 1097      5204            Joyce Carol Oates                    1996.0
# 1098    102920                Scott McCloud                    1993.0
# 1099   7842288  Kami Garcia, Margaret Stohl                    2010.0
#
#                                                          title language_code  \
# ...

# %%
books.to_csv('books.csv',encoding='utf-8',index=False)

# %%
book1 = pd.read_csv('books.csv')
book1
# Out:
#        book_id                      authors  original_publication_year  \
# 0      2767052              Suzanne Collins                     2008.0
# 1            3  J.K. Rowling, Mary GrandPré                     1997.0
# 2         2657                   Harper Lee                     1960.0
# 3         4671          F. Scott Fitzgerald                     1925.0
# 4     11870085                   John Green                     2012.0
# ...        ...                          ...                        ...
# 1080  16102004             Christina Lauren                     2013.0
# 1081     14249           Barbara Kingsolver                     2000.0
# 1082      5204            Joyce Carol Oates                     1996.0
# 1083    102920                Scott McCloud                     1993.0
# 1084   7842288  Kami Garcia, Margaret Stohl                     2010.0
#
#                                                          title language_code  \
# ...

# %%
#book1['genre_2'] = book1['genre_2'].fillna(0).astype('int64')

# %%
#book1['genre_2'] = book1['genre_2'].replace(0,'')

# %%
book_genre
# Out:
#     genre_id          genre_name
# 0          1                 Art
# 1          2           Biography
# 2          3            Business
# 3          4           Chick Lit
# 4          5          Children's
# 5          6           Christian
# 6          7            Classics
# 7          8              Comics
# 8          9        Contemporary
# 9         10           Cookbooks
# 10        11               Crime
# 11        12              Ebooks
# 12        13             Fantasy
# 13        14             Fiction
# 14        15     Gay and Lesbian
# 15        16      Graphic Novels
# 16        17  Historical Fiction
# 17        18             History
# 18        19              Horror
# 19        20    Humor and Comedy
# 20        21               Manga
# 21        22              Memoir
# 22        23               Music
# 23        24             Mystery
# 24        25          Nonfiction
# 25        26          Paranormal
# 26        27          Philosophy
# ...

# %%
book1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    1085 non-null   int64
#  1   authors                    1085 non-null   object
#  2   original_publication_year  1084 non-null   float64
#  3   title                      1085 non-null   object
#  4   language_code              1050 non-null   object
#  5   average_rating             1085 non-null   float64
#  6   image_url                  1085 non-null   object
#  7   genre_1                    1085 non-null   int64
#  8   genre_2                    1006 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 76.4+ KB
