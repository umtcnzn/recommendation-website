# %%
import pandas as pd

# %%
movie = pd.read_csv('movieswithposters.csv')
movie_genre = pd.read_csv('movieGenres.csv')

# %%
movie
# Out:
#       adult                     backdrop_path                genre_ids  \
# 0     False  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg                    [878]
# 1     False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg            [18, 878, 28]
# 2     False  /jXJxMcVoEuXzym3vFnjqDW4ifo6.jpg             [28, 12, 14]
# 3     False  /15Fe18IglCCP1jJoj5F529on0IA.jpg                 [28, 35]
# 4     False  /gg4zZoTggZmpAQ32qIrP5dtnkEZ.jpg                 [28, 80]
# ...     ...                               ...                      ...
# 1055  False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg         [28, 35, 14, 80]
# 1056  False  /tCG6iC6xTY7FfKlWxvbr40EHI9S.jpg  [16, 12, 35, 10751, 18]
# 1057  False  /cIp2F2KnPVnZ9Klw600uRkfLWu9.jpg             [16, 28, 14]
# 1058  False  /mmd1HnuvAzFc4iuVJcnBrhDNEKr.jpg                 [27, 53]
# 1059  False  /ub3BAIzgGnkHqUBtUAf3hpG9xMF.jpg          [12, 16, 10751]
#
#            id original_language  \
# 0      848326                en
# 1      695721                en
# ...

# %%
movie.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count',
#        'Genre1', 'Genre2', 'Genre3', 'Genre4', 'Genre5', 'Genre6', 'Genre7'],
#       dtype='object')

# %% [markdown]
# adult,backdrop_path,original_language,original_title,video,popularity,genre_names,vote_count
#
# ## vote olanlara bak

# %%
movie_genre
# Out:
#     genre_ids       genre_name
# 0          28           Action
# 1          12        Adventure
# 2          16        Animation
# 3          35           Comedy
# 4          80            Crime
# 5          99      Documentary
# 6          18            Drama
# 7       10751           Family
# 8          14          Fantasy
# 9          36          History
# 10         27           Horror
# 11      10402            Music
# 12       9648          Mystery
# 13      10749          Romance
# 14        878  Science Fiction
# 15      10770         TV Movie
# 16         53         Thriller
# 17      10752              War
# 18         37          Western

# %%
movie
# Out:
#       adult                     backdrop_path                genre_ids  \
# 0     False  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg                    [878]
# 1     False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg            [18, 878, 28]
# 2     False  /jXJxMcVoEuXzym3vFnjqDW4ifo6.jpg             [28, 12, 14]
# 3     False  /15Fe18IglCCP1jJoj5F529on0IA.jpg                 [28, 35]
# 4     False  /gg4zZoTggZmpAQ32qIrP5dtnkEZ.jpg                 [28, 80]
# ...     ...                               ...                      ...
# 1055  False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg         [28, 35, 14, 80]
# 1056  False  /tCG6iC6xTY7FfKlWxvbr40EHI9S.jpg  [16, 12, 35, 10751, 18]
# 1057  False  /cIp2F2KnPVnZ9Klw600uRkfLWu9.jpg             [16, 28, 14]
# 1058  False  /mmd1HnuvAzFc4iuVJcnBrhDNEKr.jpg                 [27, 53]
# 1059  False  /ub3BAIzgGnkHqUBtUAf3hpG9xMF.jpg          [12, 16, 10751]
#
#            id original_language  \
# 0      848326                en
# 1      695721                en
# ...

# %%
movie.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count',
#        'Genre1', 'Genre2', 'Genre3', 'Genre4', 'Genre5', 'Genre6', 'Genre7'],
#       dtype='object')

# %%
movie = movie.drop('adult',axis=1)
movie = movie.drop('backdrop_path',axis=1)
movie = movie.drop('genre_ids',axis=1)
movie = movie.drop('original_title',axis=1)
movie = movie.drop('popularity',axis=1)
movie = movie.drop('video',axis=1)
movie = movie.drop('vote_count',axis=1)

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
movie['Genre1'] = pd.to_numeric(movie['Genre1'], errors='coerce', downcast='integer')

# %%
movie['Genre1'] = movie['Genre1'].fillna(0).astype('int64')

# %%
movie['Genre2'] = pd.to_numeric(movie['Genre2'], errors='coerce', downcast='integer')
movie['Genre2'] = movie['Genre2'].fillna(0).astype('int64')

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
for i in range(7):
    if(i==0 or i==1):
        continue
    movie = movie.drop(f'Genre{i+1}',axis=1)

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
movie = movie.rename(columns={'Genre1': 'genre_1'})
movie = movie.rename(columns={'Genre2': 'genre_2'})

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1060 non-null   int64
#  1   original_language  1060 non-null   object
#  2   overview           1055 non-null   object
#  3   poster_path        1060 non-null   object
#  4   release_date       1059 non-null   object
#  5   title              1060 non-null   object
#  6   vote_average       1060 non-null   float64
#  7   genre_1            1060 non-null   int64
#  8   genre_2            1060 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 74.7+ KB

# %%
movie.describe()
# Out:
#                  id  vote_average       genre_1       genre_2
# count  1.060000e+03   1060.000000   1060.000000   1060.000000
# mean   4.891513e+05      6.791887   1040.908491   1825.875472
# std    3.889279e+05      1.243708   3041.513101   3909.332412
# min    1.100000e+01      0.000000      0.000000      0.000000
# 25%    6.872025e+04      6.400000     16.000000     14.000000
# 50%    4.764840e+05      6.900000     28.000000     28.000000
# 75%    8.422955e+05      7.500000     35.000000     80.000000
# max    1.217392e+06     10.000000  10770.000000  10770.000000

# %%
movie.nunique()
# Out:
# id                   1060
# original_language      30
# overview             1055
# poster_path          1060
# release_date          869
# title                1051
# vote_average           54
# genre_1                20
# genre_2                20
# dtype: int64

# %%
movie = movie.drop_duplicates()

# %%
movie = movie.fillna('')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1060 non-null   int64
#  1   original_language  1060 non-null   object
#  2   overview           1060 non-null   object
#  3   poster_path        1060 non-null   object
#  4   release_date       1060 non-null   object
#  5   title              1060 non-null   object
#  6   vote_average       1060 non-null   float64
#  7   genre_1            1060 non-null   int64
#  8   genre_2            1060 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 74.7+ KB

# %%
movie = movie.replace(0,'')

# %%
for x in movie.index:
    if movie.loc[x, 'genre_1'] == '' and movie.loc[x, 'genre_2'] == '':
        movie.drop(x,inplace=True)

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
for x in movie.index:
    if movie.loc[x, 'genre_1'] == '' or movie.loc[x, 'genre_2'] == '':
        print(movie.loc[x])
# Out:
# id                                                              848326
# original_language                                                   en
# overview             When a peaceful colony on the edge of the gala...
# poster_path          https://image.tmdb.org/t/p/original/ui4DrH1cKk...
# release_date                                                2023-12-15
# title                           Rebel Moon - Part One: A Child of Fire
# vote_average                                                       6.4
# genre_1                                                            878
# genre_2
# Name: 0, dtype: object
# id                                                              798141
# original_language                                                   en
# overview             Without warning, millions of mysterious alien ...
# poster_path          https://image.tmdb.org/t/p/original/pGPUXyhQTO...
# release_date                                                2021-03-23
# ...

# %%
movie[movie['vote_average'] == 0]
# Out:
# Empty DataFrame
# Columns: [id, original_language, overview, poster_path, release_date, title, vote_average, genre_1, genre_2]
# Index: []

# %%
movie.nunique()
# Out:
# id                   1056
# original_language      30
# overview             1052
# poster_path          1056
# release_date          868
# title                1047
# vote_average           54
# genre_1                19
# genre_2                20
# dtype: int64

# %%
movie = movie[~movie.duplicated(subset='id')]

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
movie.nunique()
# Out:
# id                   1056
# original_language      30
# overview             1052
# poster_path          1056
# release_date          868
# title                1047
# vote_average           54
# genre_1                19
# genre_2                20
# dtype: int64

# %%
movie = movie[~movie.duplicated(subset='title')]

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
movie.nunique()
# Out:
# id                   1047
# original_language      30
# overview             1043
# poster_path          1047
# release_date          859
# title                1047
# vote_average           54
# genre_1                19
# genre_2                20
# dtype: int64

# %%
duplicates = movie[movie.duplicated(subset='overview', keep=False)]
duplicates
# Out:
#           id original_language overview  \
# 43   1189927                es
# 110  1206029                es
# 138  1156593                es
# 283  1070830                es
# 613   107406                it
#
#                                            poster_path release_date  \
# 43   https://image.tmdb.org/t/p/original/nFjcIyURaX...   2023-10-12
# 110  https://image.tmdb.org/t/p/original/4lb7Lpwzu9...   2023-12-07
# 138  https://image.tmdb.org/t/p/original/3pkjbiL9ju...
# 283  https://image.tmdb.org/t/p/original/Aayn0BuqRO...   2023-01-12
# 613  https://image.tmdb.org/t/p/original/mS2FWM3so6...   1980-02-14
#
#                                   title vote_average genre_1 genre_2
# 43                             El duelo          8.5      28      35
# 110  Muchachos, la película de la gente          6.3      99
# 138                          Your Fault                   18   10749
# 283                Una aventura gigante          7.3      16
# ...

# %%
movie = movie.replace('https://image.tmdb.org/t/p/originalNone','')

# %%
for x in movie.index:
    if movie.loc[x, 'poster_path'] == '':
        movie.drop(x,inplace=True)

# %%
movie
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1055  1013860                en
# 1056     9023                en
# 1057    20982                ja
# 1058      694                en
# 1059   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1055  When Sheriff Roy Pulsipher finds himself in th...
# 1056  As a wild stallion travels across the frontier...
# 1057  Demons that once almost destroyed the world, a...
# ...

# %%
movie.to_csv('movieswithposters.csv',encoding='utf-8',index=False)

# %%
movie1 = pd.read_csv('movieswithposters.csv')
movie1
# Out:
#            id original_language  \
# 0      848326                en
# 1      695721                en
# 2      572802                en
# 3     1029575                en
# 4      891699                en
# ...       ...               ...
# 1042  1013860                en
# 1043     9023                en
# 1044    20982                ja
# 1045      694                en
# 1046   297270                en
#
#                                                overview  \
# 0     When a peaceful colony on the edge of the gala...
# 1     64 years before he becomes the tyrannical pres...
# 2     Black Manta, still driven by the need to aveng...
# 3     Dan Morgan is many things: a devoted husband, ...
# 4     A tormented father witnesses his young son die...
# ...                                                 ...
# 1042  When Sheriff Roy Pulsipher finds himself in th...
# 1043  As a wild stallion travels across the frontier...
# 1044  Demons that once almost destroyed the world, a...
# ...
