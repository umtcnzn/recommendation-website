# %%
import pandas as pd
import numpy as np

# %%
dfSeries = pd.read_csv('serieswithposters.csv')
dfSeriesGenre = pd.read_csv('seriesGenres.csv')

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date        genre_ids  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31         [16, 35]
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13         [80, 18]
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   [80, 18, 9648]
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  [80, 18, 10759]
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  [10751, 16, 35]
# ...                                ...            ...              ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03             [18]
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     [16, 35, 18]
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20          [10767]
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11      [16, 10751]
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21             [18]
#
#           id                               name origin_country  \
# ...

# %%
dfSeriesGenre
# Out:
#     genre_ids          genre_name
# 0       10759  Action & Adventure
# 1          16           Animation
# 2          35              Comedy
# 3          80               Crime
# 4          99         Documentary
# 5          18               Drama
# 6       10751              Family
# 7       10762                Kids
# 8        9648             Mystery
# 9       10763                News
# 10      10764             Reality
# 11      10765    Sci-Fi & Fantasy
# 12      10766                Soap
# 13      10767                Talk
# 14      10768      War & Politics
# 15         37             Western

# %%
dfSeries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   backdrop_path      1039 non-null   object
#  1   first_air_date     1057 non-null   object
#  2   genre_ids          1060 non-null   object
#  3   id                 1060 non-null   int64
#  4   name               1060 non-null   object
#  5   origin_country     1060 non-null   object
#  6   original_language  1060 non-null   object
#  7   original_name      1060 non-null   object
#  8   overview           1046 non-null   object
#  9   popularity         1060 non-null   float64
#  10  poster_path        1060 non-null   object
#  11  vote_average       1060 non-null   float64
#  12  vote_count         1060 non-null   int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 107.8+ KB

# %%
dfSeriesGenre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_ids   16 non-null     int64
#  1   genre_name  16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 388.0+ bytes

# %%
type(dfSeries['genre_ids'][1])
# Out:
# str

# %%
dfSeries['genre_ids'] = dfSeries['genre_ids'].str.strip('[]')

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date      genre_ids      id  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31         16, 35    1434
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13         80, 18     549
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   80, 18, 9648    2734
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  80, 18, 10759    4614
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  10751, 16, 35     456
# ...                                ...            ...            ...     ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03             18    1274
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     16, 35, 18   36041
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20          10767  117006
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11      16, 10751   61838
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21             18     638
#
# ...

# %%
dfSeries['genre_ids'] = dfSeries['genre_ids'].str.replace(',','')

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date    genre_ids      id  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31        16 35    1434
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13        80 18     549
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   80 18 9648    2734
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  80 18 10759    4614
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  10751 16 35     456
# ...                                ...            ...          ...     ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03           18    1274
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     16 35 18   36041
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20        10767  117006
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11     16 10751   61838
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21           18     638
#
# ...

# %%
def string_to_float_array_method(input_string):
    return [int(x) for x in input_string.split()]

# Assuming dfMovie is your DataFrame
for i in range(len(dfSeries['genre_ids'])):
    dfSeries['genre_ids'][i] = string_to_float_array_method(dfSeries['genre_ids'][i])
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\1640359767.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSeries['genre_ids'][i] = string_to_float_array_method(dfSeries['genre_ids'][i])
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\1640359767.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSeries['genre_ids'][i] = string_to_float_array_method(dfSeries['genre_ids'][i])
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\1640359767.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
type(dfSeries['genre_ids'][1][0])
# Out:
# int

# %%
dfSeries['genre_ids']
# Out:
# 0              [16, 35]
# 1              [80, 18]
# 2        [80, 18, 9648]
# 3       [80, 18, 10759]
# 4       [10751, 16, 35]
#              ...
# 1055               [18]
# 1056       [16, 35, 18]
# 1057            [10767]
# 1058        [16, 10751]
# 1059               [18]
# Name: genre_ids, Length: 1060, dtype: object

# %%
def find_max_length(lst):
    if isinstance(lst, list):
        return len(lst)
    else:
        return 0

# %%
def max_length_in_column(column):
    lengths = column.apply(find_max_length)
    max_length = lengths.max()
    return max_length

# %%
max_length = max_length_in_column(dfSeries['genre_ids'])
max_length
# Out:
# 7

# %%
new_columns = [f'Genre{i+1}' for i in range(max_length)]

dfSeries[new_columns] = np.nan

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date        genre_ids  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31         [16, 35]
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13         [80, 18]
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   [80, 18, 9648]
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  [80, 18, 10759]
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  [10751, 16, 35]
# ...                                ...            ...              ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03             [18]
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     [16, 35, 18]
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20          [10767]
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11      [16, 10751]
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21             [18]
#
#           id                               name origin_country  \
# ...

# %%
dfSeries['genre_names'] = [[] for _ in range(len(dfSeries))]

for i in range(len(dfSeries['genre_ids'])):
    for j in range(len(dfSeries['genre_ids'][i])):
        for k in range(len(dfSeriesGenre['genre_ids'])):
            if(dfSeries['genre_ids'][i][j]==dfSeriesGenre['genre_ids'][k]):
                dfSeries['genre_names'][i].append(dfSeriesGenre['genre_name'][k])

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date  \
# 0     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13
# 1     /mc3rG5M9dFVjMfaCFNfbD5gu2pK.jpg     2005-02-06
# 2     /nVRyd8hlg0ZLxBn9RaI7mUMQLnz.jpg     2005-09-13
# 3     /xEtiiv2uhGr9IPgeruuECIfyfin.jpg     2009-03-09
# 4     /7ajRFaUz7dW9IPsGagM8cubXPrB.jpg     2005-09-22
# ...                                ...            ...
# 1055  /woA7DdpCtbH35SczuvvHTqurhGC.jpg     2003-10-22
# 1056  /hxSEqdFRUKjn61vqNn958d08mk6.jpg     2016-12-16
# 1057  /pK22xswNJ02Hhfb9lRbXEjtXefP.jpg     2014-12-07
# 1058  /9hfA9zMsyckwZ8WLMVQYKG8YSwY.jpg     2018-09-25
# 1059  /yF0q6uOLMp3bTws9ZnSm8Ux7jXq.jpg     2023-01-17
#
#                       genre_ids  \
# 0                      [80, 18]
# 1                      [16, 35]
# 2             [18, 9648, 10765]
# 3                      [18, 80]
# 4                [80, 18, 9648]
# ...                         ...
# 1055                       [80]
# 1056  [10759, 16, 10751, 10765]
# ...

# %%
dfSeriesGenre
# Out:
#     genre_ids          genre_name
# 0       10759  Action & Adventure
# 1          16           Animation
# 2          35              Comedy
# 3          80               Crime
# 4          99         Documentary
# 5          18               Drama
# 6       10751              Family
# 7       10762                Kids
# 8        9648             Mystery
# 9       10763                News
# 10      10764             Reality
# 11      10765    Sci-Fi & Fantasy
# 12      10766                Soap
# 13      10767                Talk
# 14      10768      War & Politics
# 15         37             Western

# %%
for i in range(len(dfSeries)):
    for j in range(len(dfSeries['genre_ids'][i])):
        for k in range(len(dfSeriesGenre['genre_ids'])):
            if(dfSeries['genre_ids'][i][j]==dfSeriesGenre['genre_ids'][k]):
                dfSeries[f'Genre{j+1}'][i] = dfSeriesGenre['genre_ids'][k]
# Out:
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\3925489236.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSeries[f'Genre{j+1}'][i] = dfSeriesGenre['genre_ids'][k]
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\3925489236.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSeries[f'Genre{j+1}'][i] = dfSeriesGenre['genre_ids'][k]
# C:\Users\Dilara\AppData\Local\Temp\ipykernel_1580\3925489236.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dfSeries
# Out:
#                          backdrop_path first_air_date        genre_ids  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31         [16, 35]
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13         [80, 18]
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   [80, 18, 9648]
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  [80, 18, 10759]
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  [10751, 16, 35]
# ...                                ...            ...              ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03             [18]
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     [16, 35, 18]
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20          [10767]
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11      [16, 10751]
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21             [18]
#
#           id                               name origin_country  \
# ...

# %%
dfSeries.to_csv('serieswithposters.csv',encoding='utf-8',index=False)

# %%
dfSeries1 = pd.read_csv('serieswithposters.csv')
dfSeries1
# Out:
#                          backdrop_path first_air_date        genre_ids  \
# 0     /wU1y7snEVYiJBpZ2k1DjIpHgJbx.jpg     1999-01-31         [16, 35]
# 1     /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13         [80, 18]
# 2     /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20   [80, 18, 9648]
# 3     /6s3ftX4a1kECPCb1Ewq3GLhVFnn.jpg     2003-09-23  [80, 18, 10759]
# 4     /pxeqQX4qFQ0cVxPt5SWZENV5BH3.jpg     1989-12-17  [10751, 16, 35]
# ...                                ...            ...              ...
# 1055  /xCkQbV5g5KfEg5wGHkbUKVEhfE8.jpg     2001-06-03             [18]
# 1056  /8K5eCD8ArpdHd4lSiu4cq90Cuk4.jpg     2010-10-02     [16, 35, 18]
# 1057  /rKxuXBTBSK3pwuFj2TdjJDqtwLB.jpg     2020-02-20          [10767]
# 1058  /6ZYaLOle3iKOHlXqADnxt592v3O.jpg     2012-05-11      [16, 10751]
# 1059  /bSTSYwEO75fkA50VriI4NUWj34U.jpg     1999-09-21             [18]
#
#           id                               name origin_country  \
# ...
